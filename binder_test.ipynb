# %%
uploader = widgets.FileUpload(description = "Upload your file", multiple=False)
display(uploader)

def on_upload_change(uploaded_file):
    uploaded_file = list(uploader.value.values())[0]
    content = pd.read_excel(io.BytesIO(uploaded_file['content']))
    return display(content)
    
uploader.observe(on_upload_change, names='value')
# Out:
# FileUpload(value={}, description='Upload your file')
# C:\Users\Camer\anaconda3\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
#     Protein_μg_aliquot  Aliquot_volume_μl  Protein_μg_sample  \
# 0                  NaN                NaN                0.0
# 1                  NaN                NaN                7.5
# 2                  NaN                NaN               15.0
# 3                  NaN                NaN               30.0
# 4                  NaN                NaN               60.0
# 5                  NaN                1.0                NaN
# 6                  NaN                1.0                NaN
# 7                  NaN                1.0                NaN
# 8                  NaN                1.0                NaN
# 9                  NaN                1.0                NaN
# 10                 NaN                1.0                NaN
# 11                 NaN                1.0                NaN
# 12                 NaN                1.0                NaN
# 13                 NaN                1.0                NaN
# 14                 NaN                1.0                NaN
# 15                 NaN                1.0                NaN
# 16                 NaN                1.0                NaN
# 17                 NaN                1.0                NaN
# 18                 NaN                1.0                NaN
# 19                 NaN                1.0                NaN
# 20                 NaN                1.0                NaN
#
#     Sample_volume_ml Standard_Unknown  Condition_number  \
# 0                NaN                S                -4
# 1                NaN                S                -3
# 2                NaN                S                -2
# 3                NaN                S                -1
# 4                NaN                S                 0
# 5                0.1                U                 1
# 6                0.1                U                 1
# 7                0.1                U                 1
# 8                0.1                U                 2
# 9                0.1                U                 2
# 10               0.1                U                 2
# 11               0.1                U                 3
# 12               0.1                U                 3
# 13               0.1                U                 4
# 14               0.1                U                 4
# 15               0.1                U                 5
# 16               0.1                U                 5
# 17               0.1                U                 5
# 18               0.1                U                 6
# 19               0.1                U                 6
# 20               0.1                U                 6
#
#                      Condition_name  Replicate_number  Absorbance_nm  \
# 0                      Standard 0μg                 1          0.000
# 1                    Standard 7.5μg                 1          0.073
# 2                     Standard 15μg                 1          0.134
# 3                     Standard 30μg                 1          0.234
# 4                     Standard 60μg                 1          0.401
# 5             mitochondria kontrola                 1          0.172
# 6             mitochondria kontrola                 2          0.173
# 7             mitochondria kontrola                 3          0.144
# 8       mitochondria pacjent czyste                 1          0.193
# 9       mitochondria pacjent czyste                 2          0.188
# 10      mitochondria pacjent czyste                 3          0.181
# 11        mitochondria pacjent drug                 1          0.127
# 12        mitochondria pacjent drug                 2          0.134
# 13   mitochondria pacjent drug2 1nM                 1          0.143
# 14   mitochondria pacjent drug2 1nM                 2          0.141
# 15   mitochondria pacjent drug2 5nM                 1          0.131
# 16   mitochondria pacjent drug2 5nM                 2          0.121
# 17   mitochondria pacjent drug2 5nM                 3          0.117
# 18  mitochondria pacjent drug2 10nM                 1          0.125
# 19  mitochondria pacjent drug2 10nM                 2          0.117
# 20  mitochondria pacjent drug2 10nM                 3          0.114
#
#     Volume_for_100μg
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
# 10               NaN
# 11               NaN
# 12               NaN
# 13               NaN
# 14               NaN
# 15               NaN
# 16               NaN
# 17               NaN
# 18               NaN
# 19               NaN
# 20               NaN
